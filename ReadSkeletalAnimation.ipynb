# %%
import collada
import sys

# %%
def inspectController(controller):
    """Display contents of a controller object found in the scene."""
    print('    Controller (id=%s) (type=%s)' % (controller.skin.id, type(controller).__name__))
    print('       Vertex weights:%d, joints:%d' % (len(controller), len(controller.joint_matrices)))
    for controlled_prim in controller.primitives():
        print('       Primitive', type(controlled_prim.primitive).__name__)

def inspectGeometry(obj):
    """Display contents of a geometry object found in the scene."""
    materials = set()
    for prim in obj.primitives():
        materials.add( prim.material )

    print('    Geometry (id=%s): %d primitives'%(obj.original.id, len(obj)))
    for prim in obj.primitives():
        print('        Primitive (type=%s): len=%d vertices=%d' % (type(prim).__name__, len(prim), len(prim.vertex)))
    for mat in materials:
        if mat: inspectMaterial( mat )

def inspectMaterial(mat):
    """Display material contents."""
    print('        Material %s: shading %s'%(mat.effect.id, mat.effect.shadingtype))
    for prop in mat.effect.supported:
        value = getattr(mat.effect, prop)
        # it can be a float, a color (tuple) or a Map ( a texture )
        if isinstance(value, collada.material.Map):
            colladaimage = value.sampler.surface.image
            # Accessing this attribute forces the loading of the image
            # using PIL if available. Unless it is already loaded.
            img = colladaimage.pilimage
            if img: # can read and PIL available
                print('            %s = Texture %s:'%(prop, colladaimage.id),\
                      img.format, img.mode, img.size)
            else:
                print('            %s = Texture %s: (not available)'%(
                                   prop, colladaimage.id))
        else:
            print('            %s ='%(prop), value)

def inspectCollada(col):
    # Display the file contents
    print('File Contents:')
    print('  Geometry:')
    if col.scene is not None:
        for geom in col.scene.objects('geometry'):
            inspectGeometry( geom )
    print('  Controllers:')
    if col.scene is not None:
        for controller in col.scene.objects('controller'):
            inspectController( controller )
    print('  Cameras:')
    if col.scene is not None:
        for cam in col.scene.objects('camera'):
            print('    Camera %s: '%cam.original.id)
    print('  Lights:')
    if col.scene is not None:
        for light in col.scene.objects('light'):
            print('    Light %s: color =' % light.original.id, light.color)

    if not col.errors: print('File read without errors')
    else:
        print('Errors:')
        for error in col.errors:
            print(' ', error)

# %%
# open COLLADA file ignoring some errors in case they appear
col = collada.Collada("./models/model_horse.dae", ignore=[collada.DaeUnsupportedError, collada.DaeBrokenRefError])
inspectCollada(col)
# Out:
# File Contents:
#   Geometry:
#   Controllers:
#     Controller (id=Armature_horse-skin) (type=BoundSkin)
#        Vertex weights:7290, joints:229
#        Primitive BoundTriangleSet
#   Cameras:
#   Lights:
#     Light Sun-light: color = (1.0, 1.0, 1.0)
# File read without errors

# %%
with open('./models/process.txt') as f:
    process = f.readlines()

# %%
process_txt=[]
for txt in process:
    process_txt.append(txt[0:-1])

# %%
with open('./models/keyframe.txt') as f:
    process = f.readlines()

# %%
with open('./models/map.txt') as f:
    process = f.readlines()

# %%
map_txt=[]
for txt in process:
    map_txt.append(txt[0:-1])

# %%
keyframe_txt=[]
for txt in process:
    keyframe_txt.append(txt[0:-1])

# %%
list(set(process_txt) - set(map_txt))
# Out:
# ['Armature_Bone_005',
#  'Armature_Bone_R_011',
#  'Armature_Bone_L_005',
#  'Armature_Bone_R_010',
#  'Armature_Bone_R_004',
#  'Armature_Bone_L_006',
#  'Armature_Bone_002',
#  'Armature_Bone_R_005',
#  'Armature_Bone_R_012',
#  'Armature_Bone_008',
#  'Armature_Bone_L_002',
#  'Armature_Bone_R_002',
#  'Armature_Bone_002_R_095',
#  'Armature_Bone_R_008',
#  'Armature_Bone_L_010',
#  'Armature_Bone_R_006',
#  'Armature_Bone_003',
#  'Armature_Bone_L_011',
#  'Armature_Bone_L_008',
#  'horse',
#  'Armature_Bone_002_L',
#  'Armature_Bone_L_004',
#  'Scene',
#  'Armature_Bone_002_R',
#  'Armature',
#  'Armature_Bone_002_L_095',
#  'Armature_Bone_004',
#  'Armature_Bone_001',
#  'Sun',
#  'Armature_Bone_L_012']

# %%
process_txt
# Out:
# ['Scene',
#  'Armature',
#  'Armature_Bone',
#  'Armature_Bone_001',
#  'Armature_Bone_002',
#  'Armature_Bone_003',
#  'Armature_Bone_004',
#  'Armature_Bone_005',
#  'Armature_Bone_002_L',
#  'Armature_Bone_002_L_001',
#  'Armature_Bone_002_L_002',
#  'Armature_Bone_002_L_003',
#  'Armature_Bone_002_L_004',
#  'Armature_Bone_002_L_005',
#  'Armature_Bone_002_L_051',
#  'Armature_Bone_002_L_006',
#  'Armature_Bone_002_L_052',
#  'Armature_Bone_002_L_007',
#  'Armature_Bone_002_L_053',
#  'Armature_Bone_002_L_008',
#  'Armature_Bone_002_L_054',
#  'Armature_Bone_002_L_009',
#  'Armature_Bone_002_L_055',
#  'Armature_Bone_002_L_010',
#  'Armature_Bone_002_L_056',
#  'Armature_Bone_002_L_011',
#  'Armature_Bone_002_L_057',
#  'Armature_Bone_002_L_012',
#  'Armature_Bone_002_L_058',
#  'Armature_Bone_002_L_013',
#  'Armature_Bone_002_L_059',
#  'Armature_Bone_002_L_014',
#  'Armature_Bone_002_L_060',
#  'Armature_Bone_002_L_015',
#  'Armature_Bone_002_L_061',
#  'Armature_Bone_002_L_016',
#  'Armature_Bone_002_L_062',
#  'Armature_Bone_002_L_017',
#  'Armature_Bone_002_L_063',
#  'Armature_Bone_002_L_018',
#  'Armature_Bone_002_L_064',
#  'Armature_Bone_002_L_019',
#  'Armature_Bone_002_L_065',
#  'Armature_Bone_002_L_020',
#  'Armature_Bone_002_L_066',
#  'Armature_Bone_002_L_021',
#  'Armature_Bone_002_L_067',
#  'Armature_Bone_002_L_022',
#  'Armature_Bone_002_L_068',
#  'Armature_Bone_002_L_023',
#  'Armature_Bone_002_L_069',
#  'Armature_Bone_002_L_024',
#  'Armature_Bone_002_L_070',
#  'Armature_Bone_002_L_025',
#  'Armature_Bone_002_L_071',
#  'Armature_Bone_002_L_026',
#  'Armature_Bone_002_L_072',
#  'Armature_Bone_002_L_027',
#  'Armature_Bone_002_L_073',
#  'Armature_Bone_002_L_028',
#  'Armature_Bone_002_L_074',
#  'Armature_Bone_002_L_029',
#  'Armature_Bone_002_R_068',
#  'Armature_Bone_002_R_069',
#  'Armature_Bone_002_R_070',
#  'Armature_Bone_002_R_071',
#  'Armature_Bone_002_R_072',
#  'Armature_Bone_002_R_073',
#  'Armature_Bone_002_R_074',
#  'Armature_Bone_002_R_075',
#  'Armature_Bone_002_R_076',
#  'Armature_Bone_002_R_077',
#  'Armature_Bone_002_R_078',
#  'Armature_Bone_002_R_079',
#  'Armature_Bone_002_R_080',
#  'Armature_Bone_002_R_081',
#  'Armature_Bone_002_R_082',
#  'Armature_Bone_002_R_083',
#  'Armature_Bone_002_R_084',
#  'Armature_Bone_002_R_085',
#  'Armature_Bone_002_R_086',
#  'Armature_Bone_002_R_087',
#  'Armature_Bone_002_R_088',
#  'Armature_Bone_002_R_089',
#  'Armature_Bone_002_R_090',
#  'Armature_Bone_002_R_091',
#  'Armature_Bone_002_R_092',
#  'Armature_Bone_002_R_093',
#  'Armature_Bone_002_R_094',
#  'Armature_Bone_002_R_096',
#  'Armature_Bone_006',
#  'Armature_Bone_007',
#  'Armature_Bone_009',
#  'Armature_Bone_010',
#  'Armature_Bone_L_001',
#  'Armature_Bone_L_003',
#  'Armature_Bone_L_007',
#  'Armature_Bone_L_009',
#  'Armature_Bone_R_001',
#  'Armature_Bone_R_003',
#  'Armature_Bone_R_007',
#  'Armature_Bone_R_009',
#  'Bone_001',
#  'Bone_002',
#  'Bone_002_L',
#  'Bone_002_L_001',
#  'Bone_002_L_002',
#  'Bone_002_L_003',
#  'Bone_002_L_004',
#  'Bone_002_L_005',
#  'Bone_002_L_006',
#  'Bone_002_L_007',
#  'Bone_002_L_008',
#  'Bone_002_L_009',
#  'Bone_002_L_010',
#  'Bone_002_L_011',
#  'Bone_002_L_012',
#  'Bone_002_L_013',
#  'Bone_002_L_014',
#  'Bone_002_L_015',
#  'Bone_002_L_016',
#  'Bone_002_L_017',
#  'Bone_002_L_018',
#  'Bone_002_L_019',
#  'Bone_002_L_020',
#  'Bone_002_L_021',
#  'Bone_002_L_022',
#  'Bone_002_L_023',
#  'Bone_002_L_024',
#  'Bone_002_L_025',
#  'Bone_002_L_026',
#  'Bone_002_L_027',
#  'Bone_002_L_028',
#  'Bone_002_L_029',
#  'Bone_002_L_030',
#  'Bone_002_L_031',
#  'Bone_002_L_032',
#  'Bone_002_L_033',
#  'Bone_002_L_034',
#  'Bone_002_L_035',
#  'Bone_002_L_036',
#  'Bone_002_L_037',
#  'Bone_002_L_038',
#  'Bone_002_L_039',
#  'Bone_002_L_040',
#  'Bone_002_L_041',
#  'Bone_002_L_042',
#  'Bone_002_L_043',
#  'Bone_002_L_044',
#  'Bone_002_L_045',
#  'Bone_002_L_046',
#  'Bone_002_L_047',
#  'Bone_002_L_048',
#  'Bone_002_L_049',
#  'Bone_002_L_050',
#  'Bone_002_L_051',
#  'Bone_002_L_052',
#  'Bone_002_L_053',
#  'Bone_002_L_054',
#  'Bone_002_L_055',
#  'Bone_002_L_056',
#  'Bone_002_L_057',
#  'Bone_002_L_058',
#  'Bone_002_L_059',
#  'Bone_002_L_060',
#  'Bone_002_L_061',
#  'Bone_002_L_062',
#  'Bone_002_L_063',
#  'Bone_002_L_064',
#  'Bone_002_L_065',
#  'Bone_002_L_066',
#  'Bone_002_L_067',
#  'Bone_002_L_068',
#  'Bone_002_L_069',
#  'Bone_002_L_070',
#  'Bone_002_L_071',
#  'Bone_002_L_072',
#  'Bone_002_L_073',
#  'Bone_002_L_074',
#  'Bone_002_L_075',
#  'Bone_002_L_076',
#  'Bone_002_L_077',
#  'Bone_002_L_078',
#  'Bone_002_L_079',
#  'Bone_002_L_080',
#  'Bone_002_L_081',
#  'Bone_002_L_082',
#  'Bone_002_L_083',
#  'Bone_002_L_084',
#  'Bone_002_L_086',
#  'Bone_002_L_087',
#  'Bone_002_L_088',
#  'Bone_002_L_089',
#  'Bone_002_L_090',
#  'Bone_002_L_092',
#  'Bone_002_L_093',
#  'Bone_002_L_094',
#  'Bone_002_L_095',
#  'Bone_002_L_096',
#  'Bone_002_R',
#  'Bone_002_R_001',
#  'Bone_002_R_002',
#  'Bone_002_R_003',
#  'Bone_002_R_004',
#  'Bone_002_R_005',
#  'Bone_002_R_006',
#  'Bone_002_R_007',
#  'Bone_002_R_008',
#  'Bone_002_R_009',
#  'Bone_002_R_010',
#  'Bone_002_R_011',
#  'Bone_002_R_012',
#  'Bone_002_R_013',
#  'Bone_002_R_014',
#  'Bone_002_R_015',
#  'Bone_002_R_016',
#  'Bone_002_R_017',
#  'Bone_002_R_018',
#  'Bone_002_R_019',
#  'Bone_002_R_020',
#  'Bone_002_R_021',
#  'Bone_002_R_022',
#  'Bone_002_R_023',
#  'Bone_002_R_024',
#  'Bone_002_R_025',
#  'Bone_002_R_026',
#  'Bone_002_R_027',
#  'Bone_002_R_028',
#  'Bone_002_R_029',
#  'Bone_002_R_030',
#  'Bone_002_R_031',
#  'Bone_002_R_032',
#  'Bone_002_R_033',
#  'Bone_002_R_034',
#  'Bone_002_R_035',
#  'Bone_002_R_036',
#  'Bone_002_R_037',
#  'Bone_002_R_038',
#  'Bone_002_R_039',
#  'Bone_002_R_040',
#  'Bone_002_R_041',
#  'Bone_002_R_042',
#  'Bone_002_R_043',
#  'Bone_002_R_044',
#  'Bone_002_R_045',
#  'Bone_002_R_046',
#  'Bone_002_R_047',
#  'Bone_002_R_048',
#  'Bone_002_R_049',
#  'Bone_002_R_050',
#  'Bone_002_R_051',
#  'Bone_002_R_052',
#  'Bone_002_R_053',
#  'Bone_002_R_054',
#  'Bone_002_R_055',
#  'Bone_002_R_056',
#  'Bone_002_R_057',
#  'Bone_002_R_058',
#  'Bone_002_R_059',
#  'Bone_002_R_060',
#  'Bone_002_R_061',
#  'Bone_002_R_062',
#  'Bone_002_R_063',
#  'Bone_002_R_064',
#  'Bone_002_R_065',
#  'Bone_002_R_066',
#  'Bone_002_R_067',
#  'Bone_002_R_068',
#  'Bone_002_R_069',
#  'Bone_002_R_070',
#  'Bone_002_R_071',
#  'Bone_002_R_072',
#  'Bone_002_R_073',
#  'Bone_002_R_074',
#  'Bone_002_R_075',
#  'Bone_002_R_076',
#  'Bone_002_R_077',
#  'Bone_002_R_078',
#  'Bone_002_R_079',
#  'Bone_002_R_080',
#  'Bone_002_R_081',
#  'Bone_002_R_082',
#  'Bone_002_R_083',
#  'Bone_002_R_084',
#  'Bone_002_R_086',
#  'Bone_002_R_087',
#  'Bone_002_R_088',
#  'Bone_002_R_089',
#  'Bone_002_R_090',
#  'Bone_002_R_092',
#  'Bone_002_R_093',
#  'Bone_002_R_094',
#  'Bone_002_R_095',
#  'Bone_002_R_096',
#  'Bone_003',
#  'Bone_004',
#  'Bone_005',
#  'Bone_006',
#  'Bone_007',
#  'Bone_008',
#  'Bone_009',
#  'Bone_010',
#  'Bone_L_001',
#  'Bone_L_002',
#  'Bone_L_003',
#  'Bone_L_004',
#  'Bone_L_005',
#  'Bone_L_006',
#  'Bone_L_007',
#  'Bone_L_008',
#  'Bone_L_009',
#  'Bone_L_010',
#  'Bone_L_011',
#  'Bone_L_012',
#  'Bone_R_001',
#  'Bone_R_002',
#  'Bone_R_003',
#  'Bone_R_004',
#  'Bone_R_005',
#  'Bone_R_006',
#  'Bone_R_007',
#  'Bone_R_008',
#  'Bone_R_009',
#  'Bone_R_010',
#  'Bone_R_011',
#  'Bone_R_012']

# %%
keyframe_txt
# Out:
# ['Armature_Bone',
#  'Armature_Bone_002_L_001',
#  'Armature_Bone_002_L_002',
#  'Armature_Bone_002_L_003',
#  'Armature_Bone_002_L_004',
#  'Armature_Bone_002_L_005',
#  'Armature_Bone_002_L_051',
#  'Armature_Bone_002_L_006',
#  'Armature_Bone_002_L_052',
#  'Armature_Bone_002_L_007',
#  'Armature_Bone_002_L_053',
#  'Armature_Bone_002_L_008',
#  'Armature_Bone_002_L_054',
#  'Armature_Bone_002_L_009',
#  'Armature_Bone_002_L_055',
#  'Armature_Bone_002_L_010',
#  'Armature_Bone_002_L_056',
#  'Armature_Bone_002_L_011',
#  'Armature_Bone_002_L_057',
#  'Armature_Bone_002_L_012',
#  'Armature_Bone_002_L_058',
#  'Armature_Bone_002_L_013',
#  'Armature_Bone_002_L_059',
#  'Armature_Bone_002_L_014',
#  'Armature_Bone_002_L_060',
#  'Armature_Bone_002_L_015',
#  'Armature_Bone_002_L_061',
#  'Armature_Bone_002_L_016',
#  'Armature_Bone_002_L_062',
#  'Armature_Bone_002_L_017',
#  'Armature_Bone_002_L_063',
#  'Armature_Bone_002_L_018',
#  'Armature_Bone_002_L_064',
#  'Armature_Bone_002_L_019',
#  'Armature_Bone_002_L_065',
#  'Armature_Bone_002_L_020',
#  'Armature_Bone_002_L_066',
#  'Armature_Bone_002_L_021',
#  'Armature_Bone_002_L_067',
#  'Armature_Bone_002_L_022',
#  'Armature_Bone_002_L_068',
#  'Armature_Bone_002_L_023',
#  'Armature_Bone_002_L_069',
#  'Armature_Bone_002_L_024',
#  'Armature_Bone_002_L_070',
#  'Armature_Bone_002_L_025',
#  'Armature_Bone_002_L_071',
#  'Armature_Bone_002_L_026',
#  'Armature_Bone_002_L_072',
#  'Armature_Bone_002_L_027',
#  'Armature_Bone_002_L_073',
#  'Armature_Bone_002_L_028',
#  'Armature_Bone_002_L_074',
#  'Armature_Bone_002_L_029',
#  'Armature_Bone_002_L_075',
#  'Armature_Bone_002_L_030',
#  'Armature_Bone_002_L_076',
#  'Armature_Bone_002_L_031',
#  'Armature_Bone_002_L_077',
#  'Armature_Bone_002_L_032',
#  'Armature_Bone_002_L_078',
#  'Armature_Bone_002_L_033',
#  'Armature_Bone_002_L_079',
#  'Armature_Bone_002_L_034',
#  'Armature_Bone_002_L_080',
#  'Armature_Bone_002_L_035',
#  'Armature_Bone_002_L_081',
#  'Armature_Bone_002_L_036',
#  'Armature_Bone_002_L_082',
#  'Armature_Bone_002_L_037',
#  'Armature_Bone_002_L_083',
#  'Armature_Bone_002_L_038',
#  'Armature_Bone_002_L_084',
#  'Armature_Bone_002_L_039',
#  'Armature_Bone_002_L_085',
#  'Armature_Bone_002_L_040',
#  'Armature_Bone_002_L_086',
#  'Armature_Bone_002_L_041',
#  'Armature_Bone_002_L_087',
#  'Armature_Bone_002_L_042',
#  'Armature_Bone_002_L_088',
#  'Armature_Bone_002_L_043',
#  'Armature_Bone_002_L_089',
#  'Armature_Bone_002_L_044',
#  'Armature_Bone_002_L_090',
#  'Armature_Bone_002_L_045',
#  'Armature_Bone_002_L_091',
#  'Armature_Bone_002_L_046',
#  'Armature_Bone_002_L_092',
#  'Armature_Bone_002_L_047',
#  'Armature_Bone_002_L_093',
#  'Armature_Bone_002_L_048',
#  'Armature_Bone_002_L_094',
#  'Armature_Bone_002_L_049',
#  'Armature_Bone_002_L_050',
#  'Armature_Bone_002_L_096',
#  'Armature_Bone_002_R_001',
#  'Armature_Bone_002_R_002',
#  'Armature_Bone_002_R_003',
#  'Armature_Bone_002_R_004',
#  'Armature_Bone_002_R_005',
#  'Armature_Bone_002_R_051',
#  'Armature_Bone_002_R_006',
#  'Armature_Bone_002_R_052',
#  'Armature_Bone_002_R_007',
#  'Armature_Bone_002_R_053',
#  'Armature_Bone_002_R_008',
#  'Armature_Bone_002_R_054',
#  'Armature_Bone_002_R_009',
#  'Armature_Bone_002_R_055',
#  'Armature_Bone_002_R_010',
#  'Armature_Bone_002_R_056',
#  'Armature_Bone_002_R_011',
#  'Armature_Bone_002_R_057',
#  'Armature_Bone_002_R_012',
#  'Armature_Bone_002_R_058',
#  'Armature_Bone_002_R_013',
#  'Armature_Bone_002_R_059',
#  'Armature_Bone_002_R_014',
#  'Armature_Bone_002_R_060',
#  'Armature_Bone_002_R_015',
#  'Armature_Bone_002_R_061',
#  'Armature_Bone_002_R_016',
#  'Armature_Bone_002_R_062',
#  'Armature_Bone_002_R_017',
#  'Armature_Bone_002_R_063',
#  'Armature_Bone_002_R_018',
#  'Armature_Bone_002_R_064',
#  'Armature_Bone_002_R_019',
#  'Armature_Bone_002_R_065',
#  'Armature_Bone_002_R_020',
#  'Armature_Bone_002_R_066',
#  'Armature_Bone_002_R_021',
#  'Armature_Bone_002_R_067',
#  'Armature_Bone_002_R_022',
#  'Armature_Bone_002_R_068',
#  'Armature_Bone_002_R_023',
#  'Armature_Bone_002_R_069',
#  'Armature_Bone_002_R_024',
#  'Armature_Bone_002_R_070',
#  'Armature_Bone_002_R_025',
#  'Armature_Bone_002_R_071',
#  'Armature_Bone_002_R_026',
#  'Armature_Bone_002_R_072',
#  'Armature_Bone_002_R_027',
#  'Armature_Bone_002_R_073',
#  'Armature_Bone_002_R_028',
#  'Armature_Bone_002_R_074',
#  'Armature_Bone_002_R_029',
#  'Armature_Bone_002_R_075',
#  'Armature_Bone_002_R_030',
#  'Armature_Bone_002_R_076',
#  'Armature_Bone_002_R_031',
#  'Armature_Bone_002_R_077',
#  'Armature_Bone_002_R_032',
#  'Armature_Bone_002_R_078',
#  'Armature_Bone_002_R_033',
#  'Armature_Bone_002_R_079',
#  'Armature_Bone_002_R_034',
#  'Armature_Bone_002_R_080',
#  'Armature_Bone_002_R_035',
#  'Armature_Bone_002_R_081',
#  'Armature_Bone_002_R_036',
#  'Armature_Bone_002_R_082',
#  'Armature_Bone_002_R_037',
#  'Armature_Bone_002_R_083',
#  'Armature_Bone_002_R_038',
#  'Armature_Bone_002_R_084',
#  'Armature_Bone_002_R_039',
#  'Armature_Bone_002_R_085',
#  'Armature_Bone_002_R_040',
#  'Armature_Bone_002_R_086',
#  'Armature_Bone_002_R_041',
#  'Armature_Bone_002_R_087',
#  'Armature_Bone_002_R_042',
#  'Armature_Bone_002_R_088',
#  'Armature_Bone_002_R_043',
#  'Armature_Bone_002_R_089',
#  'Armature_Bone_002_R_044',
#  'Armature_Bone_002_R_090',
#  'Armature_Bone_002_R_045',
#  'Armature_Bone_002_R_091',
#  'Armature_Bone_002_R_046',
#  'Armature_Bone_002_R_092',
#  'Armature_Bone_002_R_047',
#  'Armature_Bone_002_R_093',
#  'Armature_Bone_002_R_048',
#  'Armature_Bone_002_R_094',
#  'Armature_Bone_002_R_049',
#  'Armature_Bone_002_R_050',
#  'Armature_Bone_002_R_096',
#  'Armature_Bone_L_007',
#  'Armature_Bone_L_009',
#  'Armature_Bone_R_007',
#  'Armature_Bone_R_009',
#  'Armature_Bone_L_001',
#  'Armature_Bone_L_003',
#  'Armature_Bone_R_001',
#  'Armature_Bone_R_003',
#  'Armature_Bone_006',
#  'Armature_Bone_007',
#  'Armature_Bone_009',
#  'Armature_Bone_010']

# %%
len(process_txt), len(map_txt), len(keyframe_txt)
# Out:
# (233, 427, 203)
